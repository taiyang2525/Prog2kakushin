# %% [markdown]
# <a href="https://colab.research.google.com/github/taiyang2525/Prog2kakushin/blob/main/work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Excel, CSVから手軽に行列の情報を求める

# %% [markdown]
# numpyを使っているそこのアナタ！numpyに行列のデータを入力するのは面倒くさくないでしょうか．
#
# いちいちnp.matrix()って書くの面倒くさいなー
#
# numpyで[ ]（大かっこ）を多用してしまうせいで，視覚的に分かりにくいなー
#
# そもそもnumpyという英語をタイプしたくないなー
#
# と感じているそこのアナタ！（特に線形代数を学習されている大学一回生！）
#
# ぜひ，このプログラムを使ってみてください！Excelで行列を入力して，アップロードするだけで，行列の演算を自動でやってくれます．

# %% [markdown]
# **以下のようにExcelで行列（説明では３次正方行列）を作成し，下のコードでアップロードすることで，行列の計算が可能となります．**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 行列１の読み込み

# %%
from google.colab import files
import pandas as pd
import numpy as np


def calc(frame):
  global matr
  array = frame.to_numpy()
  matr = np.matrix(array)
  if matr.shape[0] == 0 and matr.shape[1] == 0:
    print('ExcelファイルまたはCSVファイルに情報を入力してください．')
    uploader()
  elif matr.shape[0] == matr.shape[1]:
    display(frame)
    print(str(matr.shape[0]) + "次正方行列を読み込みました．")
    print('（空白セルは0で置換されます．）')
  else:
    display(frame)
    print(str(matr.shape[0]) + "行" + str(matr.shape[1]) + "列の行列を読み込みました．")
    print('（空白セルは0で置換されます．）')




def csv_reader(file):
  df = pd.read_csv(file, header = None)
  df = df.fillna(0) #NaNを0に置き換え
  is_numeric = df.applymap(lambda x: isinstance(x, (int, float))).all().all()
  if is_numeric:
    calc(df)
  else:
    print('ファイルに文字列が含まれます．数値のみであるかを確認してください．')
    uploader()

def excel_reader(file):
  df = pd.read_excel(file, header = None)
  df = df.fillna(0) #NaNを0に置き換え
  is_numeric = df.applymap(lambda x: isinstance(x, (int, float))).all().all()
  if is_numeric:
    calc(df)
  else:
    print('ファイルに文字列が含まれます．数値のみであるかを確認してください．')
    uploader()

def uploader():
  print('行列データをExcelファイル，またはCSVファイルで読み込んでください')
  while True:
    uploaded = files.upload()
    f_name = list(uploaded.keys())[0]
    if '.xlsx' in f_name:
      print('Excelファイルを読み込みました．')
      excel_reader(f_name)
      break
    elif '.csv' in f_name:
      print('CSVファイルを読み込みました．')
      csv_reader(f_name)
      break
    else:
      print('対応していないファイルフォーマットです．やり直してください．')

uploader()
# Out:
# 行列データをExcelファイル，またはCSVファイルで読み込んでください
#      <input type="file" id="files-33a45cc1-ec0a-4812-bc6e-991e0c285012" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33a45cc1-ec0a-4812-bc6e-991e0c285012">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ## 行列2の読み込み

# %%
from google.colab import files
import pandas as pd
import numpy as np


def calc(frame):
  global matr2
  array = frame.to_numpy()
  matr2 = np.matrix(array)
  if matr2.shape[0] == 0 and matr2.shape[1] == 0:
    print('ExcelファイルまたはCSVファイルに情報を入力してください．')
    uploader()
  elif matr2.shape[0] == matr2.shape[1]:
    display(frame)
    print(str(matr2.shape[0]) + "次正方行列を読み込みました．")
    print('（空白セルは0で置換されます．）')
  else:
    display(frame)
    print(str(matr2.shape[0]) + "行" + str(matr2.shape[1]) + "列の行列を読み込みました．")
    print('（空白セルは0で置換されます．）')




def csv_reader(file):
  df = pd.read_csv(file, header = None)
  df = df.fillna(0) #NaNを0に置き換え
  is_numeric = df.applymap(lambda x: isinstance(x, (int, float))).all().all()
  if is_numeric:
    calc(df)
  else:
    print('ファイルに文字列が含まれます．数値のみであるかを確認してください．')
    uploader()

def excel_reader(file):
  df = pd.read_excel(file, header = None)
  df = df.fillna(0) #NaNを0に置き換え
  is_numeric = df.applymap(lambda x: isinstance(x, (int, float))).all().all()
  if is_numeric:
    calc(df)
  else:
    print('ファイルに文字列が含まれます．数値のみであるかを確認してください．')
    uploader()

def uploader():
  print('行列データをExcelファイル，またはCSVファイルで読み込んでください')
  while True:
    uploaded = files.upload()
    f_name = list(uploaded.keys())[0]
    if '.xlsx' in f_name:
      print('Excelファイルを読み込みました．')
      excel_reader(f_name)
      break
    elif '.csv' in f_name:
      print('CSVファイルを読み込みました．')
      csv_reader(f_name)
      break
    else:
      print('対応していないファイルフォーマットです．やり直してください．')

uploader()
# Out:
# 行列データをExcelファイル，またはCSVファイルで読み込んでください
#      <input type="file" id="files-a8b58c3e-542d-4769-a25d-ec72b3d22ba4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8b58c3e-542d-4769-a25d-ec72b3d22ba4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ## 行列1と行列2の演算

# %%
def mode_select():
  global mode
  print('行列1と行列2で演算を行います．')
  while True:
    print('--------------------------------------')
    print('加法：1')
    print('減法：2')
    print('乗法：3')
    print('--------------------------------------')
    print()
    mode= input('数字を入力してください：')
    if mode == "1" or mode == "2" or mode == "3":
      mode = int(mode)
      break
    else:
      print('再度入力してください')

print('行列１：入力された行列')
display(pd.DataFrame(matr))
print('行列２：入力された行列')
display(pd.DataFrame(matr2))
mode_select()

if mode == 1 or mode == 2:
  if matr.shape[0] == matr2.shape[0] and matr.shape[1] == matr2.shape[1]:
    if mode == 1:
      matr_new = matr + matr2
      print('計算結果：')
      display(pd.DataFrame(matr_new))
    if mode == 2:
      matr_new = matr - matr2
      print('計算結果：')
      display(pd.DataFrame(matr_new))
  else:
    print('2つの行列の行数・列数が等しいときのみ、加法・減法は定義されます。')

elif mode == 3:
  if matr.shape[1] == matr2.shape[0]:
      matr_new = matr @ matr2
      print('計算結果：')
      display(pd.DataFrame(matr_new))
  else:
    print('行列１の列数と行列２の行数が等しいときのみ，積が定義されます．')
# Out:
# 行列１：入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 行列２：入力された行列
#     0   1  2  3  4    5   6  7
# 0  12  78  8  6  0    6  55  1
# 1  89   9  7  1  0  788   9  2
# 2   7   9  9  8  0    6   0  4
# 行列1と行列2で演算を行います．
# --------------------------------------
# 加法：1
# 減法：2
# 乗法：3
# --------------------------------------
#
# 数字を入力してください：3
# 計算結果：
#       0     1    2    3  4      5     6    7
# 0  7142  1710  714  214  0  61584  1362  200
# 1  1918  7086  838  599  0   7668  4976  135
# 2   948   708  200  123  0   7188   466   61

# %% [markdown]
# ## 行列1の計算

# %% [markdown]
# 行列のスカラー倍・n乗

# %%
def mode_select():
  global mode
  print('行列1の演算を行います．')
  while True:
    print('--------------------------------------')
    print('スカラー倍：1（行列１にスカラーcを掛ける）')
    print('n乗：2（行列1をn乗します）')
    print('--------------------------------------')
    print()
    mode = input('数字を入力してください：')
    if mode == "1" or mode == "2":
      mode = int(mode)
      break
    else:
      print('再度入力してください')


print('行列１：入力された行列')
display(pd.DataFrame(matr))
mode_select()
if mode == 1:
  print()
  c = input('スカラーcの値を入力してください，')
  if c.isnumeric() == True:
    matr_new = float(c) * matr
    print('計算結果：')
    display(pd.DataFrame(matr_new))
  else:
    print('cには数値を入力してください．')
else:
  print()
  n = input('指数nの値を入力してください，')
  if n.isnumeric() == True:
    if float(n) == int(n):
      matr_new = np.matrix(matr, dtype = object)
      matr_new = matr_new ** int(n)
      print('計算結果：')
      display(pd.DataFrame(matr_new))
    else:
      print('整数値を入力してください．')
  else:
    print('指数nには数値を入力してください．')
# Out:
# 行列１：入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 行列1の演算を行います．
# --------------------------------------
# スカラー倍：1（行列１にスカラーcを掛ける）
# n乗：2（行列1をn乗します）
# --------------------------------------
#
# 数字を入力してください：2
#
# 指数nの値を入力してください，100
# 計算結果：
#                                                    0  \
# 0  3786341967141316923871441406542524724039139115...
# 1  3966387410133776028492111876207469961422801238...
# 2  7213229533104708357909981875118136283100305537...
#
#                                                    1  \
# 0  3491081026596164874286438456417377913230152833...
# 1  3657086431161854286396409837235211840273881241...
# 2  6650738095536383138630220047357622146031042632...
#
#                                                    2
# 0  6346557499799461567456698890186473914250198285...
# 1  6648344492777346429054944789015903098585372747...
# 2  1209060787125686117638776782352321052104019804...

# %% [markdown]
# 行列１の逆行列を求める．

# %%
print('入力された行列')
display(pd.DataFrame(matr))
if matr.shape[0] != matr.shape[1]:
  print('正方行列を読み込んでください')
elif np.linalg.det(matr) == 0:
  print('行列式＝０より，正則でないため逆行列を持ちません．')
else:
  print('逆行列はこちらです')
  matr_new = np.linalg.inv(matr)
  display(pd.DataFrame(matr_new))
# Out:
# 入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 逆行列はこちらです
#           0         1         2
# 0 -0.000343  0.011992 -0.009022
# 1  0.014314 -0.000990 -0.011954
# 2 -0.014048 -0.008337  0.130082

# %% [markdown]
# 答え（matr_new行列）を出力する

# %%
print('この行列を出力します．')
display(pd.DataFrame(matr_new))
print()
a = input('エクスポートフォーマットとして，Excelファイルを希望する場合は，e，CSVファイルを希望する場合は，cと入力してください．：')
if a == "c":
  pd.DataFrame(matr_new).to_csv('answer.csv', header = False, index = False)
  print('answer.csvとして出力されました．')
elif a == "e":
  pd.DataFrame(matr_new).to_excel('answer.xlsx',header = False, index = False)
  print('answer.xlsxとして出力されました．')
else:
  print('eまたはcを入力してください．')
# Out:
# この行列を出力します．
#       0     1    2    3  4      5     6    7
# 0  7142  1710  714  214  0  61584  1362  200
# 1  1918  7086  838  599  0   7668  4976  135
# 2   948   708  200  123  0   7188   466   61
# エクスポートフォーマットとして，Excelファイルを希望する場合は，e，CSVファイルを希望する場合は，cと入力してください．：c
# answer.csvとして出力されました．

# %% [markdown]
# 行列１の行列式を求める

# %%
print('入力された行列')
display(pd.DataFrame(matr))
if matr.shape[0] != matr.shape[1]:
  print('正方行列を読み込んでください')
else:
  print('行列式の値（det）： ', np.linalg.det(matr))
# Out:
# 入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 行列式の値（det）：  -52536.00000000008

# %% [markdown]
# 行列１の固有値を求める（同一の数が出る場合は重解を意味します．）

# %%
print('入力された行列')
display(pd.DataFrame(matr))
if matr.shape[0] != matr.shape[1]:
  print('正方行列を読み込んでください')
else:
  λ = np.linalg.eig(matr)[0]
  print('固有値は以下の通りです．')
  print(λ)
# Out:
# 入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 固有値は以下の通りです．
# [ 95.233053   -72.80974741   7.57669442]

# %% [markdown]
# 階数を求める

# %%
print('入力された行列')
display(pd.DataFrame(matr))
print('階数 (rank)：', np.linalg.matrix_rank(matr))
# Out:
# 入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 階数 (rank)： 3

# %% [markdown]
# トレース（対角成分の和）を求める

# %%
print('入力された行列')
display(pd.DataFrame(matr))
print('計算結果：', np.trace(matr))
# Out:
# 入力された行列
#     0   1  2
# 0  12  78  8
# 1  89   9  7
# 2   7   9  9
# 計算結果： 30
